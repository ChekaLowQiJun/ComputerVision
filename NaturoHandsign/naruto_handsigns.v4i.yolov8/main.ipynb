# %%
#Import the YOLO model from ultralytics library
from ultralytics import YOLO

# %%
#Instantiate the model and train it with data
model = YOLO('yolov8n.pt')
results = model.train(data='d:\Machine_Learning\\naruto_hand_sign\\naruto_handsigns.v4i.yolov8\data.yaml', epochs=50) #Remember to escape certain letters or symbols
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 103MB/s]
# New https://pypi.org/project/ultralytics/8.0.165 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.163  Python-3.11.4 torch-2.0.1+cpu CPU (AMD Ryzen 5 3600X 6-Core Processor)
# ...

# %%
#Allow the model to be deployed to your webcam and predict on the captured frames
model(source=0, show=True)
